# %% [markdown]
# Extracting only the job requirements from a job description

# %%
import requests
import json

# %%
jd1 = "**Company Description**  \n\nWolt is a Helsinki\\-based fast\\-growing technology company that connects consumers with local merchants and delivery partners, providing a seamless delivery experience for a growing range of everyday essentials. We develop innovative technologies that power everything from local logistics to retail software, ensuring efficient and reliable deliveries. Our mission is to improve city life by empowering local communities and supporting their growth. As we continue to expand our offerings, we remain committed to delivering high\\-quality products and services that make life easier for our customers.\n\n\nWolt was founded in 2014 and joined forces with DoorDash in 2022\\. DoorDash operates in 31 countries today, 27 of which are with the Wolt product and brand.\n\n\nWhat’s our team?\n\n\nWe are the Storefront team, building a new greenfield product to help build Wolt scale in the long term. We aim to empower our merchants to do more business, by providing tooling and services so they can create their own online ordering experiences. These online webshops are powered by the Wolt stack and fall into a suite of products under our “New Business” domain.\n\n\nWe have bold ideas, humble attitudes and big visions for the future.\n\n\nOur goal is simple: Create a product for our merchants to generate more sales with their very own online ordering channel.\n\n\nOur team was established just over a year ago, and we released the first version of Storefront within a few months. Now, we’re looking to expand the team to accelerate our growth further, and we’d love for you to join us.\n\n **Job Description** **Who are we looking for?**\n\n\nAs a member of our team, you’ll collaborate closely with our other talented web engineers, product lead, designers, and data experts to build out our Storefront product. You’ll also work closely with our backend engineers to provide end\\-to\\-end features that help our Merchants sell more online.\n\n\nThis involves working at a fast pace across a variety of domains. One week you may be perfecting our checkout funnel to optimise our purchase conversion rates. Another week you may be creating internal tooling for our operations team to configure hundreds of Storefronts in one go. We move fast and ship impactful features on a weekly basis.\n\n\nWe also trade ideas on how to improve the product. Everyone is involved in asking questions about our product direction, making suggestions and challenging ideas. We leave our egos at the door \\& challenge ourselves to build something great. We’d hope that you can join us in this!\n\n **Qualifications** **If you …**\n\n* Are a self\\-driven and experienced Web developer with at least 3 years of experience building high\\-quality software, familiar with modern technologies and cloud platforms.\n* Are familiar with React \\& TypeScript.\n* Enjoy building high quality \\& impactful e\\-commerce websites.\n* thrive in a collaborative environment that spans across teams and countries, and you have the autonomy, ownership, and communication skills to drive projects—whether working independently or with a team.\n* Enjoy a hybrid working environment – we ask that you be based in the Tokyo area.\n\n **Additional Information** **Culture**\n\n**If you …**\n\n* Are passionate about building new products with global reach.\n* Take pride in delivering high\\-quality products and are obsessed with product growth.\n* Care about consumer pain points and don’t hesitate to roll up your sleeves and get to the very bottom of issues in the name of the customer experience.\n* Own your mistakes, and believe in the power of continuous improvement—1% better every day.\n* Learn quickly and take satisfaction in sharing your learnings with others."
jd2 = "The IQGeo Enterprise Sales team is seeking a Senior Solutions Engineer in our Tokyo office to support sales activity by providing technical and industry expertise of software products to existing and potential customers. This role is customer\\-facing and supports the Sales team and industry executives during the product evaluation process. The role will be key in formulating customer requirements and our proposed solution, responsible for the definition, implementation of product demonstrations to customers and supporting the bid process. Creating and demonstrating how the software works to solve real problems will require your ingenuity, creativity, and strong communication skills.\n\n  \n\n\n\nPosition located in Tokyo, Shibuya, with flexibility of hours, exceptional employee benefits, and possible career building experience with growth opportunities. Ideal for mid\\-level professional position with rapidly growing international tech company.\n\n  \n\n\n**Duties/Responsibilities**\n\n\n\nThe Solutions Engineer supports the sales team to drive new orders and revenue by:\n\n\n* Pro\\-actively engage in the sales cycle and take charge of the technical aspects and deliverables during the potential customer's product evaluation.\n* Meetings with customers early in the development cycle to fully appreciate and understand the problem the customer is trying to solve.\n* Define and implement appropriate demonstrations to fulfill the customer’s needs.\n* Confidently present these to the customer at the appropriate level.\n* Complete ‘Proof of Concepts’ using the IQGeo software solutions, demonstrating the value they will bring to the customer\n* Contribute to the development of proposals and estimations.\n* Represent the company at trade shows and conferences.\n* Play an active role in the introduction of new products into the market.\n* Build and maintain close links with our development and implementation teams, including reseller/implementation partners, to ensure the smooth transition from concept to production implementation.\n* Develop relationships with IT staff and key business users to position IQGeo as an enterprise partner. Answers technical questions from customers and prospects.\n* Supports the development of strategic customer account plans.\n* Support Sales with client business case development, as applicable.\n* Perform other related duties, as assigned.\n\n  \n\n\n**Required Skills/Abilities**\n\n\n* Ability to build demonstrations to present to the customer (end users, technical experts, IT experts, senior management) and internal Sales Directors.\n* Ability to analyze, clean and edit GIS data\n* (Ideally) skillset in Geospatial Information Systems (GIS) or web mapping (ESRI, QGIS).\n* Experience with any of the Cloud practices (AWS, Azure, GCP).\n* Experience with any of business applications(UI based configuration skillset)\n* Excellent communication, client relationship and interpersonal skills.\n* A hands\\-on problem solver, with ability to think on your feet and change approach as required.\n* Commitment to the success of implementation post\\-sale ensuring an effective handover to professional services organization.\n* Excellent listening and oral and written communication skills; the ability to articulate technical solutions and how they can solve customer's business problems to all audiences from the very technical to non\\-technical.\n* Excellent interpersonal and decision\\-making skills as well as the confidence to present at all levels.\n* Like to figure out things/solve interesting software problems/enjoys challenging and multiple assignments.\n* Excellent sales and customer service skills.\n* Excellent organizational skills and attention to detail.\n* Being open and flexible with regards to time management\n* Excellent time management skills with a proven ability to meet deadlines.\n* Ability to function well in a high\\-paced and at times stressful environment.\n* Proficient with Microsoft Office Suite.\n* Preference will be given to candidates who have worked with the planning and design of FTTX (i.e. fiber) networks, however it is not a requirement\n\n  \n\n\n**Education and Experience**\n\n\n* A Bachelor’s degree (or equivalent) in a relevant Engineering or Technical subject.\n* Minimum 3\\-5 years of technology and industry experience."
jd3 = "**What You'll Do**  \n\nWorking in the APJC team of the Security Services Organization, the role of a Security Consulting Engineer(SCE) is to provide technical leadership to customers across the spectrum of information and cyber security with a very strong focus on Enterprise and Service Provider Security. The role requires a mix of pre\\-sales expertise, leadership of virtual teams for delivery of complex projects, and deep and wide technical expertise to support internal and external stakeholders.  \n\nProjects vary considerably encompassing technical services such as security architecture; advising customers on people, policy and procedure issues around their security deployment; helping scope and design complex multi\\-vendor security solutions for large scale service provider networks and supporting customers in their risk and threat mitigation solutions including incident response, containment, eradication and remediation.  \n\n\n**Who You'll Work With**  \n\nIn addition to being aligned with the customers’ strategy the SCE needs to be aligned closely with all Cisco Advanced Services teams engaged at the customer. This evolvement includes helping provide clear and concise customer requirements, ensuring the team is working towards the correct solution for the customer, the customer is understanding of the solution proposed by Cisco, and that any potential gap or issue is identified and brought to the attention of the correct Cisco team members and ultimately the customer. This involvement with internal Cisco teams will include providing key account updates to management while working across functional areas with both CoE Solution Architects and Network Consulting Engineers.  \n\n  \n\n**Who You Are**\n* Design and deploy security solutions in multi\\-vendor environments\n\n\n* Develop and implement designs, standards and policies based on customer security requirements\n\n\n* Work on improving processes and automation for networking infrastructure and supporting systems\n\n\n* Significant experience of operating in an Architecture or Design role\n\n\n* Ability to simplify analysis and present results clearly at all levels of the business \\- including at senior management team level\n\n\n* Work with a worldwide team on innovations of security services\n\n\n* Represent the Cisco Security Solutions team on internal and external events\n\n**Required Skills**\n* Networking engineer with network security knowledge and experience in scripting languages such as Python, Java and PowerShell.\n\n\n* Good to have Splunk, SIEM and Big Data Mining skills\n\n\n* Knowledge of extensive security products and hands\\-on deployment knowledge in NetFlow analysis , Next\\-generation firewall/IPS, Identity Services Engine , TrustSec, Web security, Email Security , Wireless Security, Virtual Security, Cloud Security and big data analytics.\n\n\n* Substantial experience in a Network Engineer position with an Internet service provider or enterprise\\-level network.\n\n\n* Strong experience working in a Unix/Linux environment at systems administrator level.\n\n\n* Knowledge of network\\-based and system\\-level attacks and mitigation methods.\n\n\n* Knowledge of system\\-level attacks and mitigation methods with a core competency in Windows and Linux. Mac OS X is a desirable but not required.\n\n\n* Up to date knowledge of future technologies for network security in Security domains\n\n\n* Ability to know when to implement solutions and considering the impacts i.e. cost, customer impact, timescales, etc.\n\n\n* Good knowledge in modern threat detection and analysis methodologies\n\n\n* Experience of working in a technology\\-based role and interfacing to a varied number of internal and external stakeholders\n\n\n* Excellent written and verbal presentation skills.\n\n\n* Extremely strong technical account liaison and customer management, consulting skills are mandatory.\n\n\n* At least 7\\+ years of security experience is required which must include customer\\-facing roles together with clearly demonstrable experience of multi\\-vendor solutions.\n\n\n* Fluent Japanese Language skills both written and spoken\n\n\n* Business level English Language skills (reading/writing)\n\n**Desired Skills**\n* Experience developing tools to automate procedures and integration using languages such as Python, Java, Javascript or C/C\\+\\+/C\\#.\n\n\n* Bachelor’s degree or equivalent in a relevant subject is assumed and an advanced degree\n\n\n* MBA or MSc in Information Security is preferred.\n\n\n* CISSP, CISA, CISM, CEH and CHFI qualifications are all beneficial as is BS7799/ISO27000 lead auditor and Cisco Certified Design Expert (CCDE).\n\n\n* CCIE R\\&S and Security is beneficial\n\n  \n\n  \n\n**Why Cisco**  \n\nWe connect everything: people, processes, data, and things. We innovate everywhere, taking bold risks to shape the technologies that give us smart cities, connected cars, and handheld hospitals. Moreover, we do it in style with unique personalities who aren't afraid to change the way the world works, lives, plays and learns. We are thought leaders, tech geeks, pop culture aficionados, and we even have a few purple haired rock stars. We celebrate the creativity and diversity that fuels our innovation. We are dreamers and we are doers.\nWe Are Cisco\n  \n**Message to applicants applying to work in the U.S. and/or Canada:**  \n\n  \n\nWhen available, the salary range posted for this position reflects the projected hiring range for new hire, full\\-time salaries in U.S. and/or Canada locations, not including equity or benefits. For non\\-sales roles the hiring ranges reflect base salary only; employees are also eligible to receive annual bonuses. Hiring ranges for sales positions include base and incentive compensation target. Individual pay is determined by the candidate's hiring location and additional factors, including but not limited to skillset, experience, and relevant education, certifications, or training. Applicants may not be eligible for the full salary range based on their U.S. or Canada hiring location. The recruiter can share more details about compensation for the role in your location during the hiring process.\nU.S. employees have **access** to quality medical, dental and vision insurance, a 401(k) plan with a Cisco matching contribution, short and long\\-term disability coverage, basic life insurance and numerous wellbeing offerings.\n\n\nEmployees receive up to twelve paid holidays per calendar year, which includes one floating holiday (for non\\-exempt employees), plus a day off for their birthday. Non\\-Exempt new hires accrue up to 16 days of vacation time off each year, at a rate of 4\\.92 hours per pay period. Exempt new hires participate in Cisco’s flexible Vacation Time Off policy, which does not place a defined limit on how much vacation time eligible employees may use, but is subject to availability and some business limitations. All new hires are eligible for Sick Time Off subject to Cisco’s Sick Time Off Policy and will have eighty (80\\) hours of sick time off provided on their hire date and on January 1st of each year thereafter. Up to 80 hours of unused sick time will be carried forward from one calendar year to the next such that the maximum number of sick time hours an employee may have available is 160 hours. Employees in Illinois have a unique time off program designed specifically with local requirements in mind. All employees also have access to paid time away to deal with critical or emergency issues. We offer additional paid time to volunteer and give back to the community.\n\n\nEmployees on sales plans earn performance\\-based incentive pay on top of their base salary, which is split between quota and non\\-quota components. For quota\\-based incentive pay, Cisco typically pays as follows:\n\n\n.75% of incentive target for each 1% of revenue attainment up to 50% of quota;\n\n\n1\\.5% of incentive target for each 1% of attainment between 50% and 75%;\n\n\n1% of incentive target for each 1% of attainment between 75% and 100%; and once performance exceeds 100% attainment, incentive rates are at or above 1% for each 1% of attainment with no cap on incentive compensation.\n\n\nFor non\\-quota\\-based sales performance elements such as strategic sales objectives, Cisco may pay up to 125% of target. Cisco sales plans do not have a minimum threshold of performance for sales incentive compensation to be paid."
jd4 = "IT: Developer  \n\nDigital and Data Engineer  \n\nVice President\n  \n\n職務内容\n  \n\nJob Description\n- Job/Group Overview：\n  \n\n  \n\nNomura is a global financial services group with an integrated global network spanning over 30 countries. Japan IT (Information Technology) is a diverse environment with employees of over 25 nationalities, who work on technical support, application development and implementation of system changes for Japan Retail Wealth Management Business and Global Wholesale (Global Markets and Investment Banking). Nomura provides competitive employee benefits, training and upskilling opportunities, and is committed to promoting diversity, equity and inclusion, employee health and well\\-being.  \n\n野村グループは、グローバル金融サービス・グループとして、世界約30の国や地域にネットワークを有しています。日本のインフォメーション・テクノロジー部門は、25以上の国籍のメンバーが在籍する多様な環境であり、日本のリテール・ウェルスマネジメントビジネス、グローバルホールセール（グローバルマーケッツとインベストメントバンキング）において、テクニカルサポート、アプリケーション開発、システム変更などの業務に従事しています。野村グループは、充実した福利厚生、トレーニングやスキルアップの機会を提供し、ダイバーシティー、エクイティとインクルージョンの推進、従業員の健康とウェルビーイングを重視しています。  \n\n  \n\nNomura Group is a leading company in the financial services industry, having a strong global presence among Japanese financial institutions. Our mission is to contribute to the promotion of DX (digital transformation) while utilizing cutting\\-edge technology and working in harmony with our business operations. Engineers are flexibly involved in a wide variety of in\\-house development projects, and communication within the team is primarily in Japanese, but English is also used, reflecting the multinational composition of the team.  \n\n野村グループは、国内の金融機関の中で圧倒的なグローバルプレゼンスを持つ業界のリーディングカンパニーです。私たちは最先端のテクノロジーを活用し、ビジネスと一体となってDXの推進に貢献することを目指しています。エンジニアは、担当や役割に縛られず、さまざまな内製開発やプロジェクトに携わっています。チーム内のコミュニケーションは主に日本語ですが、多国籍なメンバーで構成されており、英語を使う場面もあります。  \n\n  \n\nThe Digital Tools Hub team is a group of Subject Matter Experts (SMEs) in Digital and Data, serving as a central hub between business departments and IT to promote and support digital transformation initiatives within Nomura. By maintaining and leveraging our digital tools portal, the team actively works to ensure that all employees at Nomura Group can easily find and utilize the tools they need to perform their jobs as efficiently as possible.  \n\nデジタル・ツール・ハブチームは、デジタルおよびデータに関する分野の専門家（SME）で構成されています。このチームは、野村グループ内のビジネス部門とIT部門の間の中心的なハブとして機能し、デジタルトランスフォーメーションの取り組みを促進・支援しています。さらに、チームはデジタル・ツール・ポータルを維持・活用しています。これにより、野村グループのすべての従業員が業務を可能な限り効率的に行うためのツールを見つけ、活用できるよう積極的に取り組んでいます。  \n\n  \n\n  \n\nServices provided by Digital Tools Hub are (not limited to) the following.  \n\nデジタル・ツール・ハブが提供するサービスは、次の通りです。（これだけに限定されません。）  \n\n* Governance ー EUC policy integration \\& Tool use governance\n* User adoption ー Guidance, SMEs and training materials\n* Tool Inventory ー Manage a Central Tool Inventory\n* License control ー Spend, admin and vendor management\n* Platform management ー Deployment and provisioning\n* Dev capability ー Solution build and maintain\n* Portfolio review ー Idea / Project review for efficiency in tools.\n* ガバナンス EUCのポリシー統合とツール使用のガバナンス\n* ユーザー採用 ガイダンス、SMEとトレーニング教材\n* ツール一覧 ツールカタログの管理\n* ライセンスの管理 契約、費用やベンダーの管理\n* プラットホームの管理 プラットホームの展開とプロビジョニング\n* 開発機能 ソリューションの構築と維持管理\n* ポートフォリオレビュー ツール効率性の観点からのプロジェクトレビュー\n  \n  \n\n  \n\nTools and Technology covered are (not limited to) the following.  \n\n使用されているツールとテクノロジーは、次の通りです。（これだけに限定されません。）  \n\n* Data ETL / Data Analysis (Alteryx, Python etc.)\n* Data Visualization (Power BI, Tableau etc.)\n* Data Virtualization (Denodo etc.)\n* Robotic Process Automation/RPA (UiPath, Power Automate etc.)\n* データの抽出、変換、読み込み、分析（Alteryx, Python etc.）\n* データの視覚化（Power BI, Tableau etc.）\n* データの仮想化（Denodo etc.）\n* ロボティックプロセスオートメーション RPA（UiPath, Power Automate etc.）\n  \n  \n\n  \n\n- Responsibilities：\n  \n\n  \n\nKey responsibilities to this role are (not limited to) as following.  \n\n主な職責は、次の通りです。（これだけに限定されません。）  \n\n* Active contribution to the evaluation of tools, solutions or approaches\n* Build common components for business processes simplification, consolidation and rationalization\n* Challenge the status quo and maximize opportunities for digital innovation and transformation\n* Coaching and supervising business line developers for transformation.\n* Contribute to maintenance and adherence to governance and operating model\n* Develop relationships with business line SME's to support their efforts and identify opportunities\n* Digital Transformation Culture Development via training to business users on digital tools / new technology\n* Establish accountability and ownership of solutions in case we develop for the business line\n* Maintain documentation in line with minimum standards\n* Maintain JIRA EPIC's, and stories to facilitate monitoring and planning\n* Provide transparent and clear updates as part of daily scrum calls \\- be advisory as needed\n* Propose transformation opportunities to leads\n* ツール、ソリューション、またはアプローチの評価に積極的に貢献します\n* ビジネスプロセスの簡素化、統合、合理化を目指して、共通コンポーネントを構築します\n* 現状に挑戦し、デジタルイノベーションと変革の機会を最大限に引き出します\n* 変革を推進するために、ビジネス開発担当者に対してコーチングと監督を行います\n* ガバナンスと運用モデルの維持及び順守に貢献します\n* ビジネスの専門家（SME）との関係を構築し、彼らの取り組み機会を特定してサポートします\n* デジタルツールや新技術に関するビジネスユーザー向けのトレーニングを通じて、デジタルトランスフォーメーションを促進する文化を築きます\n* ビジネス向けにソリューションを開発する際、責任とオーナーシップを明確にします\n* 基準に従って文書を適切に維持します\n* JIRA EPICとストーリーを管理し、監視と計画を容易にします\n* 毎日のスクラムコールでアップデート情報を提供し、必要に応じて助言します\n* リーダーに対して、変革のための具体的な提案を行います\n  \n\n  \n\n登録資格  \n\nRequirements\n- Requirements：\n  \n\n＜Madatory＞  \n\n* Japanese: Native or near\\-native proficiency\n* Strong communication and interpersonal skills\n* Over 5 years of experience in IT consulting or development\n* Over 5 years of experience in Data ETL, Data Analysis, or Data Engineering\n* Over 5 years of experience in SQL and RDB development\n* Ability to deliver solutions using agile or hybrid approaches to quickly meet business demands\n* Quick learner of new technologies, willing to embrace challenges, and able to actively learn and become proficient in the digital tools we adopt\n* Team player: bring the requisite skills and capabilities to the role whilst respecting those of others in the team.\n* 日本語: ネイティブまたはネイティブに近いレベル\n* 優れたコミュニケーション能力と対人スキル\n* ITコンサルティングまたは開発における5年以上の経験\n* データETL、データ分析、またはデータエンジニアリングにおける5年以上の経験\n* SQLおよびRDB開発における5年以上の経験\n* ビジネスのニーズに迅速に応えるためにアジャイルまたはハイブリッドアプローチを使用してソリューションを提供する能力\n* 新しいテクノロジーを迅速に学び、新しいことに挑戦する意欲があり、採用するデジタルツールに対して能動的に学び、習熟できる\n* チームプレーヤー ： チーム内の他のメンバーのスキルと能力を尊重しながら、役割に必要なスキルと能力をもたらす\n  \n\n＜Preferred＞  \n\n* English: Business level above\n* Experience working in Bank/Finance industry\n* Experience on Digital Transformation, Data visualization, Data virtualization\n* Project Management or BA experience\n* Digital Tools experience ー Alteryx, Power Query, Power BI, Tableau etc.\n* RPA Tools experience ー UiPath, Power Automate etc.\n* Databases ー Denodo, Sybase, Oracle, MySQL, MS SQL etc.\n* Programming languages ー Python, JavaScript, Java, etc.\n* Git, Jira, Confluence, SharePoint, MS365 etc.\n* Cloud, AI / LLM etc.\n* 英語: ビジネスレベル以上\n* 銀行 / 金融業界での実務経験\n* プロジェクト管理またはビジネス分析の経験\n* データの抽出、変換、読み込み、視覚化、仮想化の経験\n* デジタルツールの経験 Alteryx, Power Query, Power BI, Tableau etc.\n* ロボティックプロセスオートメーションの経験 UiPath, Power Automate etc.\n* データベースの経験 Denodo, Sybase, Oracle, MySQL, MS SQL etc.\n* プログラミング言語の経験 Python, JavaScript, Java, etc.\n* Git, Jira, Confluence, SharePoint, MS365 etc.\n* Cloud, AI / LLM etc.\n  \n\n  \n\n勤務地  \n\nLocation 大手町 / 豊洲"

# %%
prompt_base = ("See the following job description. " 
               "What qualifications do I need to have to work here? " 
               "Directly extract the job requirement dot points, DO NOT REPHRASE OR SUMMARIZE. "
               "Do not give me any information about the responsibilities of this role\n")

# %%
prompt = prompt_base + jd4
print(prompt)
# Out:
# See the following job description. What qualifications do I need to have to work here? Directly extract the job requirement dot points, DO NOT REPHRASE OR SUMMARIZE. Do not give me any information about the responsibilities of this role
# IT: Developer
#
# Digital and Data Engineer
#
# Vice President
#
#
# 職務内容
#
#
# Job Description
# - Job/Group Overview：
#
#
#
#
# Nomura is a global financial services group with an integrated global network spanning over 30 countries. Japan IT (Information Technology) is a diverse environment with employees of over 25 nationalities, who work on technical support, application development and implementation of system changes for Japan Retail Wealth Management Business and Global Wholesale (Global Markets and Investment Banking). Nomura provides competitive employee benefits, training and upskilling opportunities, and is committed to promoting diversity, equity and inclusion, employee health and well\-being.
#
# ...

# %% [markdown]
# Call LLM

# %%
# Define the API endpoint and headers
url = 'http://localhost:11434/api/generate'
headers = {
    'Content-Type': 'application/json'
}

# Define the data to be sent
data = {
    "model": "qwen2.5:3b",
    "prompt": prompt,
    "stream": False
}

# Convert the data to JSON format
json_data = json.dumps(data)

# Send the POST request
response = requests.post(url, headers=headers, data=json_data)

# Check if the request was successful
if response.status_code == 200:
    print('Response:', response.json())
else:
    print('Error:', response.status_code, response.text)
# Out:
# Response: {'model': 'qwen2.5:3b', 'created_at': '2025-03-07T05:25:44.85736298Z', 'response': "The job description you've provided outlines the requirements and responsibilities for a position focused on IT consulting and development, specifically in areas related to data etl, analysis, SQL development, agile or hybrid approaches, digital tools (like Alteryx and Power BI), and project management. The role requires strong communication skills, proficiency in Japanese, and over 5 years of experience in the relevant fields.\n\nHere are some key points from the job description:\n\n1. **Job Responsibilities**:\n   - Facilitate business-driven solutions using agile or hybrid approaches.\n   - Work with data etl, analysis, SQL development, and other related technologies.\n   - Collaborate with team members to provide requisite skills and abilities while respecting others' roles.\n   - Participate in the creation of digital tools like Alteryx, Power BI, Tableau, etc.\n   - Engage in project m
# ...

# %%
print(response.json()['response'])
# Out:
# The job description you've provided outlines the requirements and responsibilities for a position focused on IT consulting and development, specifically in areas related to data etl, analysis, SQL development, agile or hybrid approaches, digital tools (like Alteryx and Power BI), and project management. The role requires strong communication skills, proficiency in Japanese, and over 5 years of experience in the relevant fields.
#
# Here are some key points from the job description:
#
# 1. **Job Responsibilities**:
#    - Facilitate business-driven solutions using agile or hybrid approaches.
#    - Work with data etl, analysis, SQL development, and other related technologies.
#    - Collaborate with team members to provide requisite skills and abilities while respecting others' roles.
#    - Participate in the creation of digital tools like Alteryx, Power BI, Tableau, etc.
#    - Engage in project management or business analysis as needed.
#
# 2. **Qualifications**:
# ...
